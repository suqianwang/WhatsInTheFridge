# %%
import requests
import json

apiFTKey = "gXj2IxaxTc1YededFaHXgab6xFHbO2I76RNEmwzW"
headers = {'X-API-Key':apiFTKey}
apiFTUrl = "https://4t2d1vr498.execute-api.us-east-1.amazonaws.com/default/recom_v2"
payloadFT = json.dumps({
  "liked_recoms": [],
  "user_id": 222,
  "recom_amount": 15
})
header={"x-api-key" : apiFTKey}
responseFT = requests.post(apiFTUrl, data=payloadFT, headers=header)
if responseFT.status_code == 200:
    print(responseFT.json)
else:
    print(responseFT.status_code)
    print("Error executing API")
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(responseFT.json())
# Out:
# {'statusCode': 200, 'body': 'None', 'recom_ids': [6933, 3111, 16082, 953, 29446, 27551, 12849, 14258, 20020, 25121, 25285, 86, 22928, 14674, 8792], 'rcp_names': ['banana coconut cream dessert', 'apple cheese casserole', 'charishma s malted and yummy raisin bran snack', 'a w root beer copycat', 'denver omelette baked in the oven', 'crock pot beef stew', 'brown sugar glazed salmon', 'cajun lemon chicken spaghetti', 'chinese imperial palace general tso s chicken', 'cream cheese dill pickle bites', 'cream of pumpkin soup with cinnamon croutons', 'better than a baked potato  soup', 'coconut cranberry muffins', 'canned blueberry pie filling', 'beef tenderloin in wine sauce'], 'rcp_idxs': [6933, 3111, 16082, 953, 29446, 27551, 12849, 14258, 20020, 25121, 25285, 86, 22928, 14674, 8792], 'minutes': [15, 0, 2, 5, 35, 735, 25, 45, 60, 540, 80, 30, 35, 40, 73], 'tags': ["['15-minutes-or-less', 'time-to-make', 'preparation', 'for-large-groups', 'easy', 'number-of-servings', '3-steps-or-less']", "['15-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'low-protein', 'casseroles', 'main-dish', 'eggs-dairy', 'fruit', 'oven', 'cheese', 'dietary', 'low-in-something', 'apples', 'equipment']", "['15-minutes-or-less', 'time-to-make', 'course', 'cuisine', 'preparation', 'occasion', 'for-1-or-2', 'healthy', '5-ingredients-or-less', 'lunch', 'snacks', 'asian', 'indian', 'easy', 'kid-friendly', 'vegetarian', 'dietary', 'low-cholesterol', 'healthy-2', 'low-in-something', 'number-of-servings']", "['15-minutes-or-less', 'time-to-make', 'course', 'preparation', '5-ingredients-or-less', 'beverages', 'easy', 'kid-friendly', 'dietary', '3-steps-or-less']", "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'very-low-carbs', 'omelets-and-frittatas', 'breakfast', 'eggs-dairy', 'vegetables', 'cheese', 'eggs', 'dietary', 'low-carb', 'low-in-something', 'peppers']", "['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'healthy', 'main-dish', 'beef', 'potatoes', 'vegetables', 'american', 'potluck', 'low-fat', 'stews', 'crock-pot-slow-cooker', 'dietary', 'low-saturated-fat', 'low-calorie', 'low-carb', 'low-in-something', 'meat', 'to-go', 'equipment']", "['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'main-dish', 'seafood', 'oven', 'easy', 'diabetic', 'dinner-party', 'salmon', 'fish', 'broil', 'dietary', 'freshwater-fish', 'saltwater-fish', 'taste-mood', 'savory', 'equipment', 'presentation', 'served-hot', '3-steps-or-less']", "['weeknight', '60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'lunch', 'main-dish', 'pasta', 'poultry', 'american', 'cajun', 'southern-united-states', 'easy', 'summer', 'chicken', 'seasonal', 'inexpensive', 'meat', 'chicken-breasts', 'pasta-rice-and-grains', 'spaghetti', 'brunch']", "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'healthy', 'main-dish', 'poultry', 'asian', 'chinese', 'low-fat', 'chicken', 'dietary', 'low-saturated-fat', 'low-calorie', 'low-in-something', 'meat', 'chicken-breasts']", "['weeknight', 'time-to-make', 'course', 'cuisine', 'preparation', 'occasion', 'north-american', '5-ingredients-or-less', 'appetizers', 'american', 'southern-united-states', 'easy', 'no-cook', 'refrigerator', 'beginner-cook', 'dinner-party', 'finger-food', 'holiday-event', 'dietary', 'wedding', 'inexpensive', 'equipment', 'number-of-servings', 'presentation', 'served-cold', 'technique']", "['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'low-protein', 'bisques-cream-soups', 'soups-stews', 'vegetables', 'american', 'southern-united-states', 'oven', 'fall', 'heirloom-historical', 'holiday-event', 'winter', 'broil', 'food-processor-blender', 'stove-top', 'dietary', 'thanksgiving', 'sea ...
