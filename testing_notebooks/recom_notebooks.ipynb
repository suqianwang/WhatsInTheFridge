# %%
import requests
import json

apiFTKey = "gXj2IxaxTc1YededFaHXgab6xFHbO2I76RNEmwzW"
headers = {'X-API-Key':apiFTKey}
apiFTUrl = "https://4t2d1vr498.execute-api.us-east-1.amazonaws.com/default/recom_v2"
payloadFT = json.dumps({
  "liked_recoms": [],
  "user_id": 222,
  "recom_amount": 15
})
header={"x-api-key" : apiFTKey}
responseFT = requests.get(apiFTUrl, data=payloadFT, headers=header)
if responseFT.status_code == 200:
    print(responseFT.json)
else:
    print(responseFT.status_code)
    print("Error executing API")
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(responseFT.json())
# Out:
# {'statusCode': 200, 'body': 'None', 'recom_ids': [23741, 26397, 7540, 19457, 31109, 3380, 29670, 10453, 1025, 750, 853, 21375, 17822, 319, 30908], 'rcp_names': ['corn and cheddar cheese chowder', 'crescent jelly rolls', 'barbecued chicken salad', 'chickpea and cauliflower stew ww', 'easy cabbage soup', 'apricot nut bread', 'diet herb chicken bake', 'black eyed peas and sweet potato stew', 'absolutely awesome smoky meatballs', '50 second fudge', 'a different layered salad', 'chocolate cherry coconut macaroons', 'chicken and roasted red bell pepper ciabatta pizzas', '1 cup of coffee pork roast', 'easy asparagus side dish'], 'rcp_idxs': [23741, 26397, 7540, 19457, 31109, 3380, 29670, 10453, 1025, 750, 853, 21375, 17822, 319, 30908], 'minutes': [40, 17, 20, 25, 45, 100, 70, 90, 255, 2, 30, 35, 55, 255, 13], 'tags': ["['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'bisques-cream-soups', 'soups-stews', 'eggs-dairy', 'vegetables', 'vegetarian', 'chowders', 'cheese', 'dietary', 'corn']", "['30-minutes-or-less', 'time-to-make', 'course', 'cuisine', 'preparation', 'occasion', 'north-american', '5-ingredients-or-less', 'breads', 'breakfast', 'easy', 'beginner-cook', 'kid-friendly', 'rolls-biscuits', 'dietary', 'comfort-food', 'inexpensive', 'toddler-friendly', 'brunch', 'taste-mood', 'sweet']", "['course', 'main-ingredient', 'appetizers', 'lunch', 'poultry', 'chicken', 'sandwiches', 'meat', 'chicken-breasts']", "['weeknight', '30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'low-protein', 'healthy', 'main-dish', 'beans', 'potatoes', 'vegetables', 'indian', 'easy', 'low-fat', 'vegetarian', 'dietary', 'spicy', 'low-cholesterol', 'low-saturated-fat', 'low-calorie', 'comfort-food', 'inexpensive', 'chick-peas-garbanzos', 'healthy-2', 'low-in-something', 'cauliflower', 'taste-mood', 'from-scratch']", "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'for-large-groups', 'low-protein', 'healthy', 'soups-stews', 'vegetables', 'easy', 'low-fat', 'dietary', 'low-cholesterol', 'low-saturated-fat', 'low-calorie', 'low-in-something', 'number-of-servings', '3-steps-or-less']", "['weeknight', 'time-to-make', 'course', 'preparation', 'occasion', 'breads', 'dietary', 'gifts', 'quick-breads', '4-hours-or-less']", "['time-to-make', 'preparation', '4-hours-or-less']", "['weeknight', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'yams-sweet-potatoes', 'north-american', 'main-dish', 'beans', 'potatoes', 'vegetables', 'american', 'southern-united-states', 'potluck', 'diabetic', 'fall', 'holiday-event', 'vegan', 'vegetarian', 'stove-top', 'dietary', 'seasonal', 'comfort-food', 'inexpensive', 'peppers', 'kwanzaa', 'taste-mood', 'to-go', 'equipment', 'presentation', 'served-hot', '4-hours-or-less']", "['course', 'main-ingredient', 'preparation', 'healthy', 'appetizers', 'main-dish', 'beef', 'easy', 'crock-pot-slow-cooker', 'dietary', 'one-dish-meal', 'ground-beef', 'meat', 'equipment', '3-steps-or-less']", "['15-minutes-or-less', 'time-to-make', 'course', 'preparation', 'occasion', '5-ingredients-or-less', 'fudge', 'desserts', 'easy', 'microwave', 'beginner-cook', 'kid-friendly', 'candy', 'dietary', 'equipment']", "['30-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'occasion', 'salads', 'poultry', 'vegetables', 'no-cook', 'potluck', 'picnic', 'summer', 'chicken', 'dietary', 'seasonal', 'meat', 'to-go', 'technique']", "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'preparation', 'for-large-groups', 'drop-cookies', 'desserts', 'fruit', 'easy', 'cookies-and-brownies', 'chocolate', 'nuts', 'dietary', 'coconut', 'pitted-fruit', 'cherries', 'number-of-servings', '3-steps-or-less']", "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'for-1-or-2', 'lunch', 'main-dish', 'poultry', 'vegetables', 'easy', ' ...
