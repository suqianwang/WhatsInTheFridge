# %%
import requests

# %%
url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/findByIngredients"

querystring = {"ingredients":"red curry","number":"5","ranking":"1","ignorePantry":"true"}

headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
import json

# %%
x = response.text

# %%
print(x)
# Out:
# [{"id":264116,"title":"Butternut Squash Soup","image":"https://spoonacular.com/recipeImages/264116-312x231.jpg","imageType":"jpg","usedIngredientCount":1,"missedIngredientCount":2,"missedIngredients":[{"id":11485,"amount":1.0,"unit":"","unitLong":"","unitShort":"","aisle":"Produce","name":"butternut squash","original":"1 whole butternut squash","originalString":"1 whole butternut squash","originalName":"whole butternut squash","metaInformation":["whole"],"meta":["whole"],"extendedName":"whole butternut squash","image":"https://spoonacular.com/cdn/ingredients_100x100/butternut-squash.jpg"},{"id":6615,"amount":1.0,"unit":"cup","unitLong":"cup","unitShort":"cup","aisle":"Canned and Jarred","name":"vegetable broth","original":"1 cup vegetable broth","originalString":"1 cup vegetable broth","originalName":"vegetable broth","metaInformation":[],"meta":[],"image":"https://spoonacular.com/cdn/ingredients_100x100/chicken-broth.png"}],"usedIngredients":[{"id":2015,"amount":2.0,"unit":"tsp","un
# ...

# %%
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# "[{\"id\":618390,\"title\":\"Quick Apple Pies\",\"image\":\"https://spoonacular.com/recipeImages/618390-312x231.jpg\",\"imageType\":\"jpg\",\"usedIngredientCount\":1,\"missedIngredientCount\":2,\"missedIngredients\":[{\"id\":1123,\"amount\":1.0,\"unit\":\"\",\"unitLong\":\"\",\"unitShort\":\"\",\"aisle\":\"Milk, Eggs, Other Dairy\",\"name\":\"egg\",\"original\":\"1 Egg\",\"originalString\":\"1 Egg\",\"originalName\":\"Egg\",\"metaInformation\":[],\"meta\":[],\"image\":\"https://spoonacular.com/cdn/ingredients_100x100/egg.png\"},{\"id\":10018338,\"amount\":1.0,\"unit\":\"sheet\",\"unitLong\":\"sheet\",\"unitShort\":\"sheet\",\"aisle\":\"Refrigerated;Frozen\",\"name\":\"pastry dough\",\"original\":\"1 sheet Pastry Dough\",\"originalString\":\"1 sheet Pastry Dough\",\"originalName\":\"Pastry Dough\",\"metaInformation\":[],\"meta\":[],\"image\":\"https://spoonacular.com/cdn/ingredients_100x100/dough.jpg\"}],\"usedIngredients\":[{\"id\":9003,\"amount\":5.0,\"unit\":\"medium\",\"unitLong\"
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/697315/information"

headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"vegetarian":true,"vegan":false,"glutenFree":true,"dairyFree":true,"veryHealthy":false,"cheap":false,"veryPopular":false,"sustainable":false,"weightWatcherSmartPoints":5,"gaps":"no","lowFodmap":false,"preparationMinutes":10,"cookingMinutes":0,"aggregateLikes":3,"spoonacularScore":12.0,"healthScore":0.0,"creditsText":"Eating Well","sourceName":"Eating Well","pricePerServing":42.96,"extendedIngredients":[{"id":2015,"aisle":"Spices and Seasonings","image":"curry-powder.jpg","consistency":"solid","name":"curry powder","nameClean":"curry powder","original":"2 teaspoons curry powder","originalString":"2 teaspoons curry powder","originalName":"curry powder","amount":2.0,"unit":"teaspoons","meta":[],"metaInformation":[],"measures":{"us":{"amount":2.0,"unitShort":"tsps","unitLong":"teaspoons"},"metric":{"amount":2.0,"unitShort":"tsps","unitLong":"teaspoons"}}},{"id":19296,"aisle":"Nut butters, Jams, and Honey","image":"honey.png","consistency":"liquid","name":"honey","nameClean":"honey","ori
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/complexSearch"

querystring = {"minAlcohol":"0","maxVitaminB2":"1000","minVitaminB6":"0","maxFolicAcid":"1000","minCalories":"150","excludeIngredients":"coconut, mango","maxVitaminB6":"1000","maxVitaminB1":"1000","maxPotassium":"1000","minPotassium":"0","maxPhosphorus":"1000","minVitaminE":"0","maxSodium":"1000","maxCarbs":"100","minCholine":"0","intolerances":"peanut, shellfish","minIron":"0","number":"10","minCaffeine":"0","maxFat":"100","minVitaminB12":"0","maxSaturatedFat":"50","maxVitaminE":"1000","maxIron":"1000","maxFolate":"1000","minCholesterol":"0","minCarbs":"5","minSugar":"0","maxIodine":"1000","maxCopper":"1000","minFolate":"0","maxCalories":"1500","minZinc":"0","minSodium":"0","maxCalcium":"1000","minMagnesium":"0","maxVitaminC":"1000","maxZinc":"1000","minVitaminK":"0","maxCaffeine":"1000","minVitaminA":"0","maxAlcohol":"1000","minFiber":"0","maxVitaminB5":"1000","maxVitaminK":"1000","minManganese":"0","minFluoride":"0","cuisine":"american","minCalcium":"0","minFolicAcid":"0","minCopper":"0","maxCholesterol":"1000","minSaturatedFat":"0","maxMagnesium":"1000","minVitaminC":"0","equipment":"pan","maxVitaminB12":"1000","offset":"0","minVitaminB5":"0","maxFiber":"1000","minSelenium":"0","minVitaminB2":"0","maxSugar":"1000","minFat":"5","minVitaminB1":"0","minVitaminD":"0","maxManganese":"1000","minPhosphorus":"0","maxCholine":"1000","maxFluoride":"1000","includeIngredients":"onions, lettuce, tomato","minIodine":"0","query":"burger","maxVitaminA":"5000","minVitaminB3":"0","type":"main course","maxSelenium":"1000","maxVitaminD":"1000","minProtein":"5","maxVitaminB3":"1000","ranking":"2","maxProtein":"100"}

headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"results":[],"offset":0,"number":10,"totalResults":0}

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex?limitLicense=false&offset=0&number=10&cuisine=american&type=main%20course&includeIngredients=onions%2C%20lettuce%2C%20tomato"
url2 = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex?limitLicense=false&offset=0&number=10&query=burger&cuisine=american&includeIngredients=onions%2C%20lettuce%2C%20tomato&excludeIngredients=coconut%2C%20mango&intolerances=peanut%2C%20shellfish&type=main%20course"
url3 = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex?limitLicense=false&offset=0&number=10&query=&cuisine=american&intolerances=peanut%2Cshellfish&type=main%20course&includeIngredients=onion%2Ctomato"
headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url3, headers=headers)

print(response.text)
# Out:
# {"results":[{"id":486684,"usedIngredientCount":1,"missedIngredientCount":2,"likes":0,"title":"Chili Pot Roast","image":"https://spoonacular.com/recipeImages/486684-312x231.jpg","imageType":"jpg"},{"id":1047778,"usedIngredientCount":1,"missedIngredientCount":2,"likes":0,"title":"White Bean Turkey Chili","image":"https://spoonacular.com/recipeImages/1047778-312x231.jpg","imageType":"jpg"},{"id":527923,"usedIngredientCount":2,"missedIngredientCount":3,"likes":0,"title":"5-Ingredient Easy Chili","image":"https://spoonacular.com/recipeImages/527923-312x231.jpg","imageType":"jpg"},{"id":371202,"usedIngredientCount":2,"missedIngredientCount":3,"likes":0,"title":"Tomato-Basil Turkey Burgers","image":"https://spoonacular.com/recipeImages/371202-312x231.jpg","imageType":"jpg"},{"id":1064446,"usedIngredientCount":1,"missedIngredientCount":3,"likes":0,"title":"Vegetarian chilli","image":"https://spoonacular.com/recipeImages/1064446-312x231.jpg","imageType":"jpg"},{"id":827222,"usedIngredientCoun
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex"

querystring = {"limitLicense":"false","offset":"0","number":"10","cuisine":"american","includeIngredients":"onions, lettuce, tomato","excludeIngredients":"coconut, mango","intolerances":"peanut, shellfish","type":"main course","ranking":"2"}
headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"results":[{"id":486684,"usedIngredientCount":1,"missedIngredientCount":2,"likes":0,"title":"Chili Pot Roast","image":"https://spoonacular.com/recipeImages/486684-312x231.jpg","imageType":"jpg"},{"id":1047778,"usedIngredientCount":1,"missedIngredientCount":2,"likes":0,"title":"White Bean Turkey Chili","image":"https://spoonacular.com/recipeImages/1047778-312x231.jpg","imageType":"jpg"},{"id":278573,"usedIngredientCount":3,"missedIngredientCount":3,"likes":0,"title":"Inside-Out Cheeseburger","image":"https://spoonacular.com/recipeImages/278573-312x231.jpg","imageType":"jpg"},{"id":527923,"usedIngredientCount":2,"missedIngredientCount":3,"likes":0,"title":"5-Ingredient Easy Chili","image":"https://spoonacular.com/recipeImages/527923-312x231.jpg","imageType":"jpg"},{"id":545379,"usedIngredientCount":2,"missedIngredientCount":3,"likes":0,"title":"All A.1. Burgers","image":"https://spoonacular.com/recipeImages/545379-312x231.jpg","imageType":"jpg"},{"id":371202,"usedIngredientCount":2,"m
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/food/site/search"

querystring = {"query":"beef stroganoff sandwich"}

headers = {
    'x-rapidapi-key': "6f1810ca34msh227332a299bf704p13f30bjsn1ba98259af85",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"Recipes":[{"name":"Easy Weeknight Beef Stroganoff","image":"https://webknox.com/recipeImages/642147-556x370.jpg","link":"https://spoonacular.com/recipes/easy-weeknight-beef-stroganoff-642147","type":"HTML","relevance":69.90763854980469,"kvtable":"<table><tr><td>Cost</td><td>$1.81 per serving</td></tr><tr><td>Calories</td><td>277 Calories</td></tr><tr><td>Protein</td><td>27g Protein</td></tr><tr><td>Fat</td><td>8g Total Fat</td></tr><tr><td>Carbs</td><td>22g Carbs</td></tr></table>","dataPoints":[{"key":"Cost","value":"$1.81 per serving","show":true},{"key":"Calories","value":"277 Calories","show":true},{"key":"Protein","value":"27g Protein","show":true},{"key":"Fat","value":"8g Total Fat","show":true},{"key":"Carbs","value":"22g Carbs","show":true}]},{"name":"Classic Beef Pasta Stroganoff","image":"https://webknox.com/recipeImages/639585-556x370.jpg","link":"https://spoonacular.com/recipes/classic-beef-pasta-stroganoff-639585","type":"HTML","relevance":69.90763854980469,"kvtable":"
# ...
